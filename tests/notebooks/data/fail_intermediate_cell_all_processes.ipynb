# %%
import mpi4py
import mpi4py.MPI

# %%
# PYTEST_XFAIL: testing failure on all processes.
assert mpi4py.MPI.COMM_WORLD.size < 0

# %%
assert mpi4py.MPI.COMM_WORLD.size > 0
