# %%
import mpi4py
import mpi4py.MPI

# %%
# PYTEST_XFAIL: testing failure on some processes, regardless of the number of ranks.
assert mpi4py.MPI.COMM_WORLD.rank == 0 and mpi4py.MPI.COMM_WORLD.size > 1
